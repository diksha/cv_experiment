# %%
import sys, os

sys.path.append(os.environ["BUILD_WORKSPACE_DIRECTORY"])
from lib.ml.inference.tasks.object_detection_2d.yolov5.post_processing_model import (
    transform_and_post_process,
    unpack_observations,
)
from lib.ml.inference.tasks.object_detection_2d.yolov5.utils import (
    preprocess_image,
)
from core.utils.aws_utils import (
    download_to_file,
    separate_bucket_from_relative_path,
)

# %%
import tempfile
import torch


def get_yolo_model(use_s3: bool = False):
    model_path = "s3://voxel-users/common/yolo/automated/2021-12-06-00-00-00-0000-yolo/best.torchscript.pt"
    named_temporary_file = tempfile.NamedTemporaryFile()
    bucket, path = separate_bucket_from_relative_path(model_path)
    local_model_path = (
        "/home/tim/tmp/modesto_experiment/best_960.torchscript.pt"
    )
    if use_s3:
        download_to_file(bucket, path, named_temporary_file.name)
        local_model_path = named_temporary_file.name

    yolo_model = torch.jit.load(local_model_path)
    yolo_model = yolo_model.to("cuda")
    return yolo_model

# %%
import typing


class YoloWithPostProcessing(torch.nn.Module):
    def __init__(self, model):
        super().__init__()
        self.model = model

    def forward(
        self,
        input_tensor: torch.Tensor,
        offset: torch.Tensor,
        scale: torch.Tensor,
        classes: torch.Tensor,
        confidence_threshold: torch.Tensor,
        nms_threshold: torch.Tensor,
    ):
        prediction = self.model(input_tensor)[0]
        return transform_and_post_process(
            prediction,
            offset,
            scale,
            classes,
            confidence_threshold,
            nms_threshold,
        )


yolo_model = get_yolo_model()

composed_model = YoloWithPostProcessing(yolo_model)

# %%
import cv2


def get_example_image():
    # rickroll image
    img_url = (
        "https://i.kym-cdn.com/photos/images/facebook/000/377/946/0b9.jpg"
    )
    # https://stackoverflow.com/questions/30229231/python-save-image-from-url
    import requests

    img_data = requests.get(img_url).content
    with tempfile.NamedTemporaryFile(suffix=".jpg") as tmp:
        with open(tmp.name, "wb") as handler:
            handler.write(img_data)

        return cv2.imread(tmp.name)

# %%
example_image = get_example_image()

# %%
sample_input_shape = [480, 960]  # height, width from configs
import numpy as np

# images are height, width, channels in opencv
batched_input = torch.from_numpy(get_example_image()).unsqueeze(0)
processed, offset, scale = preprocess_image(
    batched_input, sample_input_shape, "cuda"
)

# %%
scripted_model = torch.jit.script(
    composed_model,
    example_inputs=[
        (
            processed,
            offset,
            scale,
            torch.tensor([0, 1]),
            torch.tensor([0.7]),
            torch.tensor([0.2]),
        )
    ],
)
# Out:
# /home/tim/.cache/bazel/_bazel_tim/2d5638d889f325f1ad1d1c69ba2aada2/execroot/voxel/bazel-out/k8-fastbuild/bin/third_party/jupyter/jupyter.runfiles/pip_deps_torch/site-packages/torch/jit/_script.py:1280: UserWarning: Warning: monkeytype is not installed. Please install https://github.com/Instagram/MonkeyType to enable Profile-Directed Typing in TorchScript. Refer to https://github.com/Instagram/MonkeyType/blob/master/README.rst to install MonkeyType.
#   warnings.warn("Warning: monkeytype is not installed. Please install https://github.com/Instagram/MonkeyType "

# %%
scripted_model
# Out:
# RecursiveScriptModule(
#   original_name=YoloWithPostProcessing
#   (model): RecursiveScriptModule(
#     original_name=Model
#     (model): RecursiveScriptModule(
#       original_name=Sequential
#       (0): RecursiveScriptModule(
#         original_name=Conv
#         (conv): RecursiveScriptModule(original_name=Conv2d)
#         (act): RecursiveScriptModule(original_name=SiLU)
#       )
#       (1): RecursiveScriptModule(
#         original_name=Conv
#         (conv): RecursiveScriptModule(original_name=Conv2d)
#         (act): RecursiveScriptModule(original_name=SiLU)
#       )
#       (2): RecursiveScriptModule(
#         original_name=C3
#         (cv1): RecursiveScriptModule(
#           original_name=Conv
#           (conv): RecursiveScriptModule(original_name=Conv2d)
#           (act): RecursiveScriptModule(original_name=SiLU)
#         )
#         (cv2): RecursiveScriptModule(
#           original_name=Conv
#           (conv): RecursiveScriptModule(original_name=Conv2d)
#           (act): RecursiveScriptModule(original_name=SiLU)
#         )
#         (cv3): RecursiveScriptModule(
#           original_name=Conv
#           (conv): RecursiveScriptModule(original_name=Conv2d)
#           (act): RecursiveScriptModule(original_name=SiLU)
#         )
#         (m): RecursiveScriptModule(
#           original_name=Sequential
#           (0): RecursiveScriptModule(
#             original_name=Bottleneck
#             (cv1): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#             (cv2): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#           )
#           (1): RecursiveScriptModule(
#             original_name=Bottleneck
#             (cv1): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#             (cv2): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#           )
#         )
#       )
#       (3): RecursiveScriptModule(
#         original_name=Conv
#         (conv): RecursiveScriptModule(original_name=Conv2d)
#         (act): RecursiveScriptModule(original_name=SiLU)
#       )
#       (4): RecursiveScriptModule(
#         original_name=C3
#         (cv1): RecursiveScriptModule(
#           original_name=Conv
#           (conv): RecursiveScriptModule(original_name=Conv2d)
#           (act): RecursiveScriptModule(original_name=SiLU)
#         )
#         (cv2): RecursiveScriptModule(
#           original_name=Conv
#           (conv): RecursiveScriptModule(original_name=Conv2d)
#           (act): RecursiveScriptModule(original_name=SiLU)
#         )
#         (cv3): RecursiveScriptModule(
#           original_name=Conv
#           (conv): RecursiveScriptModule(original_name=Conv2d)
#           (act): RecursiveScriptModule(original_name=SiLU)
#         )
#         (m): RecursiveScriptModule(
#           original_name=Sequential
#           (0): RecursiveScriptModule(
#             original_name=Bottleneck
#             (cv1): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#             (cv2): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#           )
#           (1): RecursiveScriptModule(
#             original_name=Bottleneck
#             (cv1): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#             (cv2): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#           )
#           (2): RecursiveScriptModule(
#             original_name=Bottleneck
#             (cv1): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#             (cv2): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#           )
#           (3): RecursiveScriptModule(
#             original_name=Bottleneck
#             (cv1): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#             (cv2): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#           )
#         )
#       )
#       (5): RecursiveScriptModule(
#         original_name=Conv
#         (conv): RecursiveScriptModule(original_name=Conv2d)
#         (act): RecursiveScriptModule(original_name=SiLU)
#       )
#       (6): RecursiveScriptModule(
#         original_name=C3
#         (cv1): RecursiveScriptModule(
#           original_name=Conv
#           (conv): RecursiveScriptModule(original_name=Conv2d)
#           (act): RecursiveScriptModule(original_name=SiLU)
#         )
#         (cv2): RecursiveScriptModule(
#           original_name=Conv
#           (conv): RecursiveScriptModule(original_name=Conv2d)
#           (act): RecursiveScriptModule(original_name=SiLU)
#         )
#         (cv3): RecursiveScriptModule(
#           original_name=Conv
#           (conv): RecursiveScriptModule(original_name=Conv2d)
#           (act): RecursiveScriptModule(original_name=SiLU)
#         )
#         (m): RecursiveScriptModule(
#           original_name=Sequential
#           (0): RecursiveScriptModule(
#             original_name=Bottleneck
#             (cv1): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#             (cv2): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#           )
#           (1): RecursiveScriptModule(
#             original_name=Bottleneck
#             (cv1): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#             (cv2): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#           )
#           (2): RecursiveScriptModule(
#             original_name=Bottleneck
#             (cv1): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#             (cv2): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#           )
#           (3): RecursiveScriptModule(
#             original_name=Bottleneck
#             (cv1): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#             (cv2): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#           )
#           (4): RecursiveScriptModule(
#             original_name=Bottleneck
#             (cv1): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#             (cv2): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#           )
#           (5): RecursiveScriptModule(
#             original_name=Bottleneck
#             (cv1): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#             (cv2): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#           )
#         )
#       )
#       (7): RecursiveScriptModule(
#         original_name=Conv
#         (conv): RecursiveScriptModule(original_name=Conv2d)
#         (act): RecursiveScriptModule(original_name=SiLU)
#       )
#       (8): RecursiveScriptModule(
#         original_name=C3
#         (cv1): RecursiveScriptModule(
#           original_name=Conv
#           (conv): RecursiveScriptModule(original_name=Conv2d)
#           (act): RecursiveScriptModule(original_name=SiLU)
#         )
#         (cv2): RecursiveScriptModule(
#           original_name=Conv
#           (conv): RecursiveScriptModule(original_name=Conv2d)
#           (act): RecursiveScriptModule(original_name=SiLU)
#         )
#         (cv3): RecursiveScriptModule(
#           original_name=Conv
#           (conv): RecursiveScriptModule(original_name=Conv2d)
#           (act): RecursiveScriptModule(original_name=SiLU)
#         )
#         (m): RecursiveScriptModule(
#           original_name=Sequential
#           (0): RecursiveScriptModule(
#             original_name=Bottleneck
#             (cv1): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#             (cv2): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#           )
#           (1): RecursiveScriptModule(
#             original_name=Bottleneck
#             (cv1): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#             (cv2): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#           )
#         )
#       )
#       (9): RecursiveScriptModule(
#         original_name=SPPF
#         (cv1): RecursiveScriptModule(
#           original_name=Conv
#           (conv): RecursiveScriptModule(original_name=Conv2d)
#           (act): RecursiveScriptModule(original_name=SiLU)
#         )
#         (cv2): RecursiveScriptModule(
#           original_name=Conv
#           (conv): RecursiveScriptModule(original_name=Conv2d)
#           (act): RecursiveScriptModule(original_name=SiLU)
#         )
#         (m): RecursiveScriptModule(original_name=MaxPool2d)
#       )
#       (10): RecursiveScriptModule(
#         original_name=Conv
#         (conv): RecursiveScriptModule(original_name=Conv2d)
#         (act): RecursiveScriptModule(original_name=SiLU)
#       )
#       (11): RecursiveScriptModule(original_name=Upsample)
#       (12): RecursiveScriptModule(original_name=Concat)
#       (13): RecursiveScriptModule(
#         original_name=C3
#         (cv1): RecursiveScriptModule(
#           original_name=Conv
#           (conv): RecursiveScriptModule(original_name=Conv2d)
#           (act): RecursiveScriptModule(original_name=SiLU)
#         )
#         (cv2): RecursiveScriptModule(
#           original_name=Conv
#           (conv): RecursiveScriptModule(original_name=Conv2d)
#           (act): RecursiveScriptModule(original_name=SiLU)
#         )
#         (cv3): RecursiveScriptModule(
#           original_name=Conv
#           (conv): RecursiveScriptModule(original_name=Conv2d)
#           (act): RecursiveScriptModule(original_name=SiLU)
#         )
#         (m): RecursiveScriptModule(
#           original_name=Sequential
#           (0): RecursiveScriptModule(
#             original_name=Bottleneck
#             (cv1): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#             (cv2): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#           )
#           (1): RecursiveScriptModule(
#             original_name=Bottleneck
#             (cv1): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#             (cv2): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#           )
#         )
#       )
#       (14): RecursiveScriptModule(
#         original_name=Conv
#         (conv): RecursiveScriptModule(original_name=Conv2d)
#         (act): RecursiveScriptModule(original_name=SiLU)
#       )
#       (15): RecursiveScriptModule(original_name=Upsample)
#       (16): RecursiveScriptModule(original_name=Concat)
#       (17): RecursiveScriptModule(
#         original_name=C3
#         (cv1): RecursiveScriptModule(
#           original_name=Conv
#           (conv): RecursiveScriptModule(original_name=Conv2d)
#           (act): RecursiveScriptModule(original_name=SiLU)
#         )
#         (cv2): RecursiveScriptModule(
#           original_name=Conv
#           (conv): RecursiveScriptModule(original_name=Conv2d)
#           (act): RecursiveScriptModule(original_name=SiLU)
#         )
#         (cv3): RecursiveScriptModule(
#           original_name=Conv
#           (conv): RecursiveScriptModule(original_name=Conv2d)
#           (act): RecursiveScriptModule(original_name=SiLU)
#         )
#         (m): RecursiveScriptModule(
#           original_name=Sequential
#           (0): RecursiveScriptModule(
#             original_name=Bottleneck
#             (cv1): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#             (cv2): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#           )
#           (1): RecursiveScriptModule(
#             original_name=Bottleneck
#             (cv1): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#             (cv2): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#           )
#         )
#       )
#       (18): RecursiveScriptModule(
#         original_name=Conv
#         (conv): RecursiveScriptModule(original_name=Conv2d)
#         (act): RecursiveScriptModule(original_name=SiLU)
#       )
#       (19): RecursiveScriptModule(original_name=Concat)
#       (20): RecursiveScriptModule(
#         original_name=C3
#         (cv1): RecursiveScriptModule(
#           original_name=Conv
#           (conv): RecursiveScriptModule(original_name=Conv2d)
#           (act): RecursiveScriptModule(original_name=SiLU)
#         )
#         (cv2): RecursiveScriptModule(
#           original_name=Conv
#           (conv): RecursiveScriptModule(original_name=Conv2d)
#           (act): RecursiveScriptModule(original_name=SiLU)
#         )
#         (cv3): RecursiveScriptModule(
#           original_name=Conv
#           (conv): RecursiveScriptModule(original_name=Conv2d)
#           (act): RecursiveScriptModule(original_name=SiLU)
#         )
#         (m): RecursiveScriptModule(
#           original_name=Sequential
#           (0): RecursiveScriptModule(
#             original_name=Bottleneck
#             (cv1): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#             (cv2): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#           )
#           (1): RecursiveScriptModule(
#             original_name=Bottleneck
#             (cv1): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#             (cv2): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#           )
#         )
#       )
#       (21): RecursiveScriptModule(
#         original_name=Conv
#         (conv): RecursiveScriptModule(original_name=Conv2d)
#         (act): RecursiveScriptModule(original_name=SiLU)
#       )
#       (22): RecursiveScriptModule(original_name=Concat)
#       (23): RecursiveScriptModule(
#         original_name=C3
#         (cv1): RecursiveScriptModule(
#           original_name=Conv
#           (conv): RecursiveScriptModule(original_name=Conv2d)
#           (act): RecursiveScriptModule(original_name=SiLU)
#         )
#         (cv2): RecursiveScriptModule(
#           original_name=Conv
#           (conv): RecursiveScriptModule(original_name=Conv2d)
#           (act): RecursiveScriptModule(original_name=SiLU)
#         )
#         (cv3): RecursiveScriptModule(
#           original_name=Conv
#           (conv): RecursiveScriptModule(original_name=Conv2d)
#           (act): RecursiveScriptModule(original_name=SiLU)
#         )
#         (m): RecursiveScriptModule(
#           original_name=Sequential
#           (0): RecursiveScriptModule(
#             original_name=Bottleneck
#             (cv1): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#             (cv2): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#           )
#           (1): RecursiveScriptModule(
#             original_name=Bottleneck
#             (cv1): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#             (cv2): RecursiveScriptModule(
#               original_name=Conv
#               (conv): RecursiveScriptModule(original_name=Conv2d)
#               (act): RecursiveScriptModule(original_name=SiLU)
#             )
#           )
#         )
#       )
#       (24): RecursiveScriptModule(
#         original_name=Detect
#         (m): RecursiveScriptModule(
#           original_name=ModuleList
#           (0): RecursiveScriptModule(original_name=Conv2d)
#           (1): RecursiveScriptModule(original_name=Conv2d)
#           (2): RecursiveScriptModule(original_name=Conv2d)
#         )
#       )
#     )
#   )
# )

# %%
from loguru import logger

try:
    torch.onnx.export(
        scripted_model,
        args=((processed, offset, scale, [0, 1], 0.7, 0.2),),
        f="foo.onnx",
    )
except RuntimeError as e:
    print(f"Model was not able to be traced with error {e}")
    logger.exception("error was found")
# Out:
# 2023-04-11 17:54:15.542 | ERROR    | __main__:<module>:11 - error was found
# Traceback (most recent call last):
#
#   File "/home/tim/.cache/bazel/_bazel_tim/2d5638d889f325f1ad1d1c69ba2aada2/external/python_x86_64-unknown-linux-gnu/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#            │         │     └ {'__name__': '__main__', '__doc__': 'Entry point for launching an IPython kernel.\n\nThis is separate from the ipykernel pack...
#            │         └ <code object <module> at 0x7f64785b2ea0, file "/home/tim/.cache/bazel/_bazel_tim/2d5638d889f325f1ad1d1c69ba2aada2/execroot/vo...
#            └ <function _run_code at 0x7f6478577550>
#   File "/home/tim/.cache/bazel/_bazel_tim/2d5638d889f325f1ad1d1c69ba2aada2/external/python_x86_64-unknown-linux-gnu/lib/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#          │     └ {'__name__': '__main__', '__doc__': 'Entry point for launching an IPython kernel.\n\nThis is separate from the ipykernel pack...
#          └ <code object <module> at 0x7f64785b2ea0, file "/home/tim/.cache/bazel/_bazel_tim/2d5638d889f325f1ad1d1c69ba2aada2/execroot/vo...
#
#   File "/home/tim/.cache/bazel/_bazel_tim/2d5638d889f325f1ad1d1c69ba2aada2/execroot/voxel/bazel-out/k8-fastbuild/bin/third_party/jupyter/jupyter.runfiles/pip_deps_ipykernel/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#     │   └ <bound method Application.launch_instance of <class 'ipykernel.kernelapp.IPKernelApp'>>
#     └ <module 'ipykernel.kernelapp' from '/home/tim/.cache/bazel/_bazel_tim/2d5638d889f325f1ad1d1c69ba2aada2/execroot/voxel/bazel-o...
#
#   File "/home/tim/.cache/bazel/_bazel_tim/2d5638d889f325f1ad1d1c69ba2aada2/execroot/voxel/bazel-out/k8-fastbuild/bin/third_party/jupyter/jupyter.runfiles/pip_deps_traitlets/site-packages/traitlets/config/application.py", line 976, in launch_instance
#     app.start()
#     │   └ <function IPKernelApp.start at 0x7f647492b9d0>
#     └ <ipykernel.kernelapp.IPKernelApp object at 0x7f6478567970>
#
#   File "/home/tim/.cache/bazel/_bazel_tim/2d5638d889f325f1ad1d1c69ba2aada2/execroot/voxel/bazel-out/k8-fastbuild/bin/third_party/jupyter/jupyter.runfiles/pip_deps_ipykernel/site-packages/ipykernel/kernelapp.py", line 712, in start
#     self.io_loop.start()
#     │    │       └ <function BaseAsyncIOLoop.start at 0x7f6476446040>
#     │    └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x7f64749296a0>
#     └ <ipykernel.kernelapp.IPKernelApp object at 0x7f6478567970>
#
#   File "/home/tim/.cache/bazel/_bazel_tim/2d5638d889f325f1ad1d1c69ba2aada2/execroot/voxel/bazel-out/k8-fastbuild/bin/third_party/jupyter/jupyter.runfiles/pip_deps_tornado/site-packages/tornado/platform/asyncio.py", line 215, in start
#     self.asyncio_loop.run_forever()
#     │    │            └ <function BaseEventLoop.run_forever at 0x7f647816a160>
#     │    └ <_UnixSelectorEventLoop running=True closed=False debug=False>
#     └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x7f64749296a0>
#
#   File "/home/tim/.cache/bazel/_bazel_tim/2d5638d889f325f1ad1d1c69ba2aada2/external/python_x86_64-unknown-linux-gnu/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#     self._run_once()
#     │    └ <function BaseEventLoop._run_once at 0x7f647816cca0>
#     └ <_UnixSelectorEventLoop running=True closed=False debug=False>
#   File "/home/tim/.cache/bazel/_bazel_tim/2d5638d889f325f1ad1d1c69ba2aada2/external/python_x86_64-unknown-linux-gnu/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#     handle._run()
#     │      └ <function Handle._run at 0x7f64782488b0>
#     └ <Handle <TaskWakeupMethWrapper object at 0x7f64700a3160>(<Future finis...eb0>, ...],))>)>
#   File "/home/tim/.cache/bazel/_bazel_tim/2d5638d889f325f1ad1d1c69ba2aada2/external/python_x86_64-unknown-linux-gnu/lib/python3.9/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#     │    │            │    │           │    └ <member '_args' of 'Handle' objects>
#     │    │            │    │           └ <Handle <TaskWakeupMethWrapper object at 0x7f64700a3160>(<Future finis...eb0>, ...],))>)>
#     │    │            │    └ <member '_callback' of 'Handle' objects>
#     │    │            └ <Handle <TaskWakeupMethWrapper object at 0x7f64700a3160>(<Future finis...eb0>, ...],))>)>
#     │    └ <member '_context' of 'Handle' objects>
#     └ <Handle <TaskWakeupMethWrapper object at 0x7f64700a3160>(<Future finis...eb0>, ...],))>)>
#
#   File "/home/tim/.cache/bazel/_bazel_tim/2d5638d889f325f1ad1d1c69ba2aada2/execroot/voxel/bazel-out/k8-fastbuild/bin/third_party/jupyter/jupyter.runfiles/pip_deps_ipykernel/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#           │    └ <function Kernel.process_one at 0x7f6475533ca0>
#           └ <ipykernel.ipkernel.IPythonKernel object at 0x7f64748f40a0>
#
#   File "/home/tim/.cache/bazel/_bazel_tim/2d5638d889f325f1ad1d1c69ba2aada2/execroot/voxel/bazel-out/k8-fastbuild/bin/third_party/jupyter/jupyter.runfiles/pip_deps_ipykernel/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#           │         └ ([<zmq.sugar.frame.Frame object at 0x7f63af960ca0>, <zmq.sugar.frame.Frame object at 0x7f63af960d50>, <zmq.sugar.frame.Frame ...
#           └ <bound method Kernel.dispatch_shell of <ipykernel.ipkernel.IPythonKernel object at 0x7f64748f40a0>>
#
#   File "/home/tim/.cache/bazel/_bazel_tim/2d5638d889f325f1ad1d1c69ba2aada2/execroot/voxel/bazel-out/k8-fastbuild/bin/third_party/jupyter/jupyter.runfiles/pip_deps_ipykernel/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#           └ <coroutine object Kernel.execute_request at 0x7f63af95a940>
#
#   File "/home/tim/.cache/bazel/_bazel_tim/2d5638d889f325f1ad1d1c69ba2aada2/execroot/voxel/bazel-out/k8-fastbuild/bin/third_party/jupyter/jupyter.runfiles/pip_deps_ipykernel/site-packages/ipykernel/kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#                           └ <coroutine object IPythonKernel.do_execute at 0x7f63af95ee40>
#
#   File "/home/tim/.cache/bazel/_bazel_tim/2d5638d889f325f1ad1d1c69ba2aada2/execroot/voxel/bazel-out/k8-fastbuild/bin/third_party/jupyter/jupyter.runfiles/pip_deps_ipykernel/site-packages/ipykernel/ipkernel.py", line 383, in do_execute
#     res = shell.run_cell(
#           │     └ <function ZMQInteractiveShell.run_cell at 0x7f647491f310>
#           └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f64748f4910>
#
#   File "/home/tim/.cache/bazel/_bazel_tim/2d5638d889f325f1ad1d1c69ba2aada2/execroot/voxel/bazel-out/k8-fastbuild/bin/third_party/jupyter/jupyter.runfiles/pip_deps_ipykernel/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#                              │       └ {'store_history': True, 'silent': False, 'cell_id': None}
#                              └ ('from loguru import logger\n\ntry:\n    torch.onnx.export(\n        scripted_model,\n        args=((processed, offset, scale...
#
#   File "/home/tim/.cache/bazel/_bazel_tim/2d5638d889f325f1ad1d1c69ba2aada2/execroot/voxel/bazel-out/k8-fastbuild/bin/third_party/jupyter/jupyter.runfiles/pip_deps_ipython/site-packages/IPython/core/interactiveshell.py", line 2961, in run_cell
#     result = self._run_cell(
#              │    └ <function InteractiveShell._run_cell at 0x7f6475dd6160>
#              └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f64748f4910>
#
#   File "/home/tim/.cache/bazel/_bazel_tim/2d5638d889f325f1ad1d1c69ba2aada2/execroot/voxel/bazel-out/k8-fastbuild/bin/third_party/jupyter/jupyter.runfiles/pip_deps_ipython/site-packages/IPython/core/interactiveshell.py", line 3016, in _run_cell
#     result = runner(coro)
#              │      └ <coroutine object InteractiveShell.run_cell_async at 0x7f6474995c40>
#              └ <function _pseudo_sync_runner at 0x7f6475dc5a60>
#
#   File "/home/tim/.cache/bazel/_bazel_tim/2d5638d889f325f1ad1d1c69ba2aada2/execroot/voxel/bazel-out/k8-fastbuild/bin/third_party/jupyter/jupyter.runfiles/pip_deps_ipython/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#     │    └ <method 'send' of 'coroutine' objects>
#     └ <coroutine object InteractiveShell.run_cell_async at 0x7f6474995c40>
#
#   File "/home/tim/.cache/bazel/_bazel_tim/2d5638d889f325f1ad1d1c69ba2aada2/execroot/voxel/bazel-out/k8-fastbuild/bin/third_party/jupyter/jupyter.runfiles/pip_deps_ipython/site-packages/IPython/core/interactiveshell.py", line 3221, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                        │    │             │        │     └ '/tmp/ipykernel_1946410/3187218794.py'
#                        │    │             │        └ [<ast.ImportFrom object at 0x7f63ae92b1f0>, <ast.Try object at 0x7f63ae92bdf0>]
#                        │    │             └ <ast.Module object at 0x7f63ae92bd60>
#                        │    └ <function InteractiveShell.run_ast_nodes at 0x7f6475dd6430>
#                        └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f64748f4910>
#
#   File "/home/tim/.cache/bazel/_bazel_tim/2d5638d889f325f1ad1d1c69ba2aada2/execroot/voxel/bazel-out/k8-fastbuild/bin/third_party/jupyter/jupyter.runfiles/pip_deps_ipython/site-packages/IPython/core/interactiveshell.py", line 3400, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#              │    │        │     │              └ False
#              │    │        │     └ <ExecutionResult object at 7f63b7647610, execution_count=9 error_before_exec=None error_in_exec=None info=<ExecutionInfo obje...
#              │    │        └ <code object <module> at 0x7f63af960a80, file "/tmp/ipykernel_1946410/3187218794.py", line 3>
#              │    └ <function InteractiveShell.run_code at 0x7f6475dd64c0>
#              └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f64748f4910>
#
#   File "/home/tim/.cache/bazel/_bazel_tim/2d5638d889f325f1ad1d1c69ba2aada2/execroot/voxel/bazel-out/k8-fastbuild/bin/third_party/jupyter/jupyter.runfiles/pip_deps_ipython/site-packages/IPython/core/interactiveshell.py", line 3460, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#          │         │    │               │    └ {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, ...
#          │         │    │               └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f64748f4910>
#          │         │    └ <property object at 0x7f6475dcc540>
#          │         └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f64748f4910>
#          └ <code object <module> at 0x7f63af960a80, file "/tmp/ipykernel_1946410/3187218794.py", line 3>
#
# > File "/tmp/ipykernel_1946410/3187218794.py", line 4, in <module>
#     torch.onnx.export(
#     │     │    └ <function export at 0x7f63c96df280>
#     │     └ <module 'torch.onnx' from '/home/tim/.cache/bazel/_bazel_tim/2d5638d889f325f1ad1d1c69ba2aada2/execroot/voxel/bazel-out/k8-fas...
#     └ <module 'torch' from '/home/tim/.cache/bazel/_bazel_tim/2d5638d889f325f1ad1d1c69ba2aada2/execroot/voxel/bazel-out/k8-fastbuil...
#
#   File "/home/tim/.cache/bazel/_bazel_tim/2d5638d889f325f1ad1d1c69ba2aada2/execroot/voxel/bazel-out/k8-fastbuild/bin/third_party/jupyter/jupyter.runfiles/pip_deps_torch/site-packages/torch/onnx/utils.py", line 504, in export
#     _export(
#     └ <function _export at 0x7f63c96e2160>
#
#   File "/home/tim/.cache/bazel/_bazel_tim/2d5638d889f325f1ad1d1c69ba2aada2/execroot/voxel/bazel-out/k8-fastbuild/bin/third_party/jupyter/jupyter.runfiles/pip_deps_torch/site-packages/torch/onnx/utils.py", line 1529, in _export
#     graph, params_dict, torch_out = _model_to_graph(
#                                     └ <function _model_to_graph at 0x7f63c96dfdc0>
#
#   File "/home/tim/.cache/bazel/_bazel_tim/2d5638d889f325f1ad1d1c69ba2aada2/execroot/voxel/bazel-out/k8-fastbuild/bin/third_party/jupyter/jupyter.runfiles/pip_deps_torch/site-packages/torch/onnx/utils.py", line 1111, in _model_to_graph
#     graph, params, torch_out, module = _create_jit_graph(model, args)
#                                        │                 │      └ ((tensor([[[[0.4471, 0.4471, 0.4471,  ..., 0.4471, 0.4471, 0.4471],
#                                        │                 │                  [0.4471, 0.4471, 0.4471,  ..., 0.4471, 0.4471, ...
#                                        │                 └ RecursiveScriptModule(
#                                        │                     original_name=YoloWithPostProcessing
#                                        │                     (model): RecursiveScriptModule(
#                                        │                       original_name=Model
#                                        │                       (...
#                                        └ <function _create_jit_graph at 0x7f63c96dfaf0>
#
#   File "/home/tim/.cache/bazel/_bazel_tim/2d5638d889f325f1ad1d1c69ba2aada2/execroot/voxel/bazel-out/k8-fastbuild/bin/third_party/jupyter/jupyter.runfiles/pip_deps_torch/site-packages/torch/onnx/utils.py", line 972, in _create_jit_graph
#     graph = _C._propagate_and_assign_input_shapes(
#             │  └ <built-in method _propagate_and_assign_input_shapes of PyCapsule object at 0x7f6451161750>
#             └ <module 'torch._C' from '/home/tim/.cache/bazel/_bazel_tim/2d5638d889f325f1ad1d1c69ba2aada2/execroot/voxel/bazel-out/k8-fastb...
#
# RuntimeError: input_values.size() == param_count_list.size() INTERNAL ASSERT FAILED at "../torch/csrc/jit/python/script_init.cpp":491, please report a bug to PyTorch.  input_values:170 vs param_count_list:165
# Model was not able to be traced with error input_values.size() == param_count_list.size() INTERNAL ASSERT FAILED at "../torch/csrc/jit/python/script_init.cpp":491, please report a bug to PyTorch.  input_values:170 vs param_count_list:165

# %%
cuda_scripted = scripted_model.to("cuda")

# %%
cuda_scripted_inputs = [
    tuple(
        tensor.to("cuda")
        for tensor in (
            processed,
            torch.tensor([offset]),
            torch.tensor(scale),
            torch.tensor([0, 1]),
            torch.tensor([0.7]),
            torch.tensor([0.2]),
        )
    )
]

# %%
cuda_scripted_model = torch.jit.script(
    cuda_scripted, example_inputs=cuda_scripted_inputs
)

# %%
model_save_path = "/home/tim/tmp/yolo_torchscript_postprocess.pt"
cuda_scripted_model.save(model_save_path)

# %%
import torch
from google.protobuf.json_format import ParseDict
from tritonclient.grpc import model_config_pb2

from core.utils.yaml_jinja import load_yaml_with_jinja
from lib.ml.inference.backends.triton import TritonInferenceBackend

# from lib.infra.utils.resolve_model_path import resolve_model_path

# model protos are defined here:
# https://github.com/triton-inference-server/common/blob/main/protobuf/model_config.proto


def test_postprocessing():
    """
    Tests yolo on the triton remote inference server
    """
    config_dict = {
        "name": "yolov5_postprocessing",
        "platform": "pytorch_libtorch",
        "max_batch_size": 16,
        "input": [
            {
                "name": "input0",
                "data_type": "TYPE_FP16",
                "dims": [28350, 7],
            },
            {
                "name": "input1",
                "data_type": "TYPE_FP16",
                "dims": [2],
            },
            {
                "name": "input2",
                "data_type": "TYPE_FP16",
                "dims": [2],
            },
            {
                "name": "input3",
                "data_type": "TYPE_INT32",
                "dims": [2],
            },
            {
                "name": "input4",
                "data_type": "TYPE_FP16",
                "dims": [1],
            },
            {
                "name": "input5",
                "data_type": "TYPE_FP16",
                "dims": [1],
            },
        ],
        "output": [
            {
                "name": "output0",
                "data_type": "TYPE_INT64",
                "dims": [1],
            },
            {
                "name": "output1",
                "data_type": "TYPE_FP32",
                "dims": [9],
            },
        ],
    }

    triton_config = model_config_pb2.ModelConfig()
    ParseDict(config_dict, triton_config)
    model_path = "/home/tim/tmp/yolo_torchscript_postprocess2.pt"

    backend = TritonInferenceBackend(
        model_name=model_path,
        triton_config=triton_config,
    )
    return backend
# Out:
# /home/tim/.cache/bazel/_bazel_tim/2d5638d889f325f1ad1d1c69ba2aada2/execroot/voxel/bazel-out/k8-fastbuild/bin/third_party/jupyter/jupyter.runfiles/pip_deps_tritonclient/site-packages/tritonclient/grpc/__init__.py:60: UserWarning: Imported version of grpc is 1.46.3. There is a memory leak in certain Python GRPC versions (1.43.0 to be specific). Please use versions <1.43.0 or >=1.51.1 to avoid leaks (see https://github.com/grpc/grpc/issues/28513).
#   warnings.warn(

# %%
from lib.ml.inference.backends.triton import (
    InferInput,
    InferRequestedOutput,
)
import numpy as np


def generate_inputs(input_tensors):
    backend = test_postprocessing()
    inputs = [
        InferInput(f"input{i}", input_size, "FP16")
        if i != 3
        else InferInput(f"input{i}", input_size, "INT32")
        for i, input_size in enumerate(
            ([1, 28350, 7], [1, 2], [1, 2], [1, 2], [1, 1], [1, 1])
        )
    ]
    for i, input_ in enumerate(input_tensors):
        if i != 3:
            inputs[i].set_data_from_numpy(input_.numpy().astype(np.float16))
        else:
            inputs[i].set_data_from_numpy(input_.numpy().astype(np.int32))
    outputs = [
        InferRequestedOutput("output0"),
        InferRequestedOutput("output1"),
    ]
    results = backend.triton_client.infer(
        model_name="home_tim_tmp_yolo_torchscript_postprocess2.pt",
        inputs=inputs,
        outputs=outputs,
    )
    # the raw output leads to undefined behavior since the numpy reference is not writable
    # so we have to copy this
    return results

# %%
a = yolo_model(cuda_scripted_inputs[0][0])
inputs_ = list(i.cpu() for i in cuda_scripted_inputs[0])

# %%
from lib.ml.inference.tasks.object_detection_2d.yolov5.post_processing_model import (
    transform_and_post_process,
    unpack_observations,
)


class PostProcessing(torch.nn.Module):
    def __init__(self):
        super().__init__()

    def forward(
        self,
        prediction: torch.Tensor,
        offset: torch.Tensor,
        scale: torch.Tensor,
        classes: torch.Tensor,
        confidence_threshold: torch.Tensor,
        nms_threshold: torch.Tensor,
    ):
        return transform_and_post_process(
            prediction,
            offset,
            scale,
            classes,
            confidence_threshold,
            nms_threshold,
        )

# %%
p_model = PostProcessing()

# %%
cuda_p_model = p_model.to("cuda")

# %%
for c in cuda_scripted_inputs[1:]:
    c = c.unsqueeze()

# %%
# cuda_scripted_inputs[0] = (csi.unsqueeze(dim=0) for i, csi in enumerate(cuda_scripted_inputs[0]) if i> 0)

# %%
# cuda_scripted_inputs[0] = tuple(cuda_scripted_inputs[0])

# %%
cuda_scripted_inputs = [
    tuple(
        tensor.to("cuda")
        for tensor in (
            a[0],
            torch.tensor([offset]),
            torch.tensor([scale]),
            torch.tensor([[0, 1]]),
            torch.tensor([[0.7]]),
            torch.tensor([[0.2]]),
        )
    )
]

# %%
cuda_scripted_inputs
# Out:
# [(tensor([[[4.8254e+00, 6.7972e+00, 8.8472e+00,  ..., 8.2012e-09,
#             6.2281e-01, 3.4054e-01],
#            [1.5298e+01, 7.2738e+00, 2.1923e+01,  ..., 2.3744e-09,
#             4.7648e-01, 5.1285e-01],
#            [2.1765e+01, 7.6465e+00, 2.8101e+01,  ..., 1.0994e-08,
#             7.0488e-01, 3.0642e-01],
#            ...,
#            [8.7527e+02, 4.5789e+02, 1.4945e+02,  ..., 3.0573e-08,
#             6.4081e-01, 1.3216e-01],
#            [9.1796e+02, 4.6129e+02, 1.5803e+02,  ..., 9.0671e-08,
#             5.8365e-01, 1.6683e-01],
#            [9.4555e+02, 4.6236e+02, 1.8089e+02,  ..., 8.3444e-08,
#             6.0037e-01, 1.5930e-01]]], device='cuda:0'),
#   tensor([[158.,   0.]], device='cuda:0'),
#   tensor([[0.6486, 0.6486]], device='cuda:0'),
#   tensor([[0, 1]], device='cuda:0'),
#   tensor([[0.7000]], device='cuda:0'),
#   tensor([[0.2000]], device='cuda:0'))]

# %%
for c in cuda_scripted_inputs[0]:
    print(c.size())
# Out:
# torch.Size([1, 28350, 7])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 1])
# torch.Size([1, 1])

# %%
c_scripted_model = torch.jit.script(
    cuda_p_model, example_inputs=cuda_scripted_inputs
)

# %%
model_save_path = "/home/tim/tmp/yolo_torchscript_postprocess2.pt"
c_scripted_model.save(model_save_path)

# %%
# generate_inputs(cuda_scripted_inputs[0])
cpu_inputs = list(
    cuda_scripted_input.cpu()
    for cuda_scripted_input in cuda_scripted_inputs[0]
)

# %%
a = generate_inputs(cpu_inputs)

# %%
a
