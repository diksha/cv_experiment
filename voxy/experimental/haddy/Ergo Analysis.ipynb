n_foods/hayward/0008/cha/scenarios/BAD_POSTURE/NEGATIVE/3e01b697-0e51-454d-ad4b-7972574e3e9a_0000",
    "ppg/cedar_falls/0008/cha/scenarios/BAD_POSTURE/NEGATIVE/24cf1e94-8e81-4606-9bc9-00f702ad7c14_0000",
    "uscold/quakertown/0008/cha/scenarios/BAD_POSTURE/NEGATIVE/3be75671-e42b-4e07-a5ea-11bb49146bb0_0000",
    "ppg/cedar_falls/0011/cha/scenarios/BAD_POSTURE/NEGATIVE/9bc71aff-bee0-49c7-9240-85c69df5cc79_0000",
    "ppg/cedar_falls/0007/cha/scenarios/BAD_POSTURE/NEGATIVE/2c1dfdbc-9a84-4e9e-8cbc-32048774830a_0000",
    "western_carriers/north_bergen/0003/cha/scenarios/BAD_POSTURE/NEGATIVE/fb077277-10d4-42e6-b126-41554d1c9ee3_0000",
    "wn_foods/hayward/0008/cha/scenarios/BAD_POSTURE/NEGATIVE/6f631abf-7610-49d9-8659-b99c8e5179b0_0000",
    "verst/walton/0005/cha/scenarios/BAD_POSTURE/NEGATIVE/a6a4a0c7-1fd2-49e1-8f8e-ae7615a99b9b_0000",
    "ppg/cedar_falls/0007/cha/scenarios/BAD_POSTURE/NEGATIVE/83a30355-198a-4021-8119-8e343a416242_0000",
    "verst/walton/0004/cha/scenarios/BAD_POSTURE/NEGATIVE/92d38606-2399-4de3-99d4-cb0cac4b9a4c_0000",
    "feb_distributing/biloxi/0009/cha/scenarios/BAD_POSTURE/NEGATIVE/483e9e62-788c-4bc5-832d-01e91990e497_0000",
    "verst/walton/0003/cha/scenarios/BAD_POSTURE/NEGATIVE/2a54bc7c-68e8-425a-a5f4-0528cab53387_0000",
}
fn_no_filter = {
    "uscold/laredo/dock01/cha/scenarios/BAD_POSTURE/POSITIVE/4a5c95f7-c0b6-4c12-b54e-1f30589a6190_0000",
    "uscold/laredo/dock01/cha/scenarios/BAD_POSTURE/POSITIVE/2be75d6c-4464-4fcb-8b31-284678271050_0000",
    "innovate_manufacturing/knoxville/0006/cha/scenarios/BAD_POSTURE/POSITIVE/36636ca5-2d3c-453a-b97c-4776eccac934_0000",
    "piston_automotive/marion/0002/cha/scenarios/BAD_POSTURE/POSITIVE/6e1d8512-41ff-4d17-ad4a-4b0e0cbe0af1_0000",
    "lakeshore_beverage/arlington_heights/0002/cha/scenarios/BAD_POSTURE/POSITIVE/abdea2a0-dcca-4f30-85b0-8018a76e211f_0000",
    "ppg/cedar_falls/0011/cha/scenarios/BAD_POSTURE/POSITIVE/5d9cfee4-726f-4b63-8606-65afcefcd2e4_0000",
    "innovate_manufacturing/knoxville/0005/cha/scenarios/BAD_POSTURE/POSITIVE/09649c80-7484-40b7-9b0e-babf27346ba0_0000",
    "ppg/cedar_falls/0008/cha/scenarios/BAD_POSTURE/POSITIVE/c7af9926-3bf0-4c52-84b9-23258b6c0f58_0000",
    "wesco/reno/0005/cha/scenarios/BAD_POSTURE/POSITIVE/265d19e3-901f-4e26-962e-3f7f4ee1b15d_0000",
    "uscold/laredo/dock01/cha/scenarios/BAD_POSTURE/POSITIVE/08071448-19ea-45a6-b248-1d490f58e330_0000",
    "lakeshore_beverage/arlington_heights/0001/cha/scenarios/BAD_POSTURE/POSITIVE/72158087-e8f8-4767-b3f7-0b2d46dd70f0_0000",
}

# %%
print("FP and FN with double carry object classifier model:")
print(len(fp_with_double_carry_object_classifier))
print(len(fn_with_double_carry_object_classifier))

print(" ")
print("FP and FN with bending model:")
print(len(fp_with_bending_model))
print(len(fn_with_bending_model))

print(" ")
print("FP and FN with HM model:")
print(len(fp_with_HM_model))
print(len(fn_with_HM_model))

print(" ")
print("FP and FN with No Filter:")
print(len(fp_no_filter))
print(len(fn_no_filter))
# Out:
# FP and FN with double carry object classifier model:
# 22
# 12
#
# FP and FN with bending model:
# 22
# 14
#
# FP and FN with HM model:
# 22
# 12
#
# FP and FN with No Filter:
# 27
# 11

# %%
# print("")
# print("fp_with_double_carry_object_classifier - fp_with_bending_model")
# print(fp_with_double_carry_object_classifier.difference(fp_with_bending_model))

# print("")
# print("fp_with_bending_model - fp_with_double_carry_object_classifier")
# print(fp_with_bending_model.difference(fp_with_double_carry_object_classifier))

# print("")
# print("fn_with_double_carry_object_classifier - fn_with_bending_model")
# print(fn_with_double_carry_object_classifier.difference(fn_with_bending_model))

# print("")
# print("fn_with_bending_model - fn_with_double_carry_object_classifier")
# print(fn_with_bending_model.difference(fn_with_double_carry_object_classifier))

# # HM Model vs double_carry_object_classifier
# print("")
# print("fp_with_double_carry_object_classifier - fp_with_HM_model")
# print(fp_with_double_carry_object_classifier.difference(fp_with_HM_model))

# print("")
# print("fp_with_HM_model - fp_with_double_carry_object_classifier")
# print(fp_with_HM_model.difference(fp_with_double_carry_object_classifier))

# print("")
# print("fn_with_double_carry_object_classifier - fn_with_HM_model")
# print(fn_with_double_carry_object_classifier.difference(fn_with_HM_model))

# print("")
# print("fn_with_HM_model - fn_with_double_carry_object_classifier")
# print(fn_with_HM_model.difference(fn_with_double_carry_object_classifier))

# # HM Model vs bending_model
# print("")
# print("fp_with_bending_model - fp_with_HM_model")
# print(fp_with_bending_model.difference(fp_with_HM_model))

# print("")
# print("fp_with_HM_model - fp_with_bending_model")
# print(fp_with_HM_model.difference(fp_with_bending_model))

# print("")
# print("fn_with_bending_model - fn_with_HM_model")
# print(fn_with_bending_model.difference(fn_with_HM_model))

# print("")
# print("fn_with_HM_model - fn_with_bending_model")
# print(fn_with_HM_model.difference(fn_with_bending_model))

##############################NO FILTER vs HM FILTER################################

# No Filter vs HM Filter
print("")
print("fp_no_filter - fp_with_HM_model")
print(fp_no_filter.difference(fp_with_HM_model))

print("")
print("fp_with_HM_model - fp_no_filter")
print(fp_with_HM_model.difference(fp_no_filter))

print("")
print("fn_no_filter - fn_with_HM_model")
print(fn_no_filter.difference(fn_with_HM_model))

print("")
print("fn_with_HM_model - fn_no_filter")
print(fn_with_HM_model.difference(fn_no_filter))
# Out:
# fp_no_filter - fp_with_HM_model
# {'wn_foods/hayward/0008/cha/scenarios/BAD_POSTURE/NEGATIVE/6f631abf-7610-49d9-8659-b99c8e5179b0_0000', 'buildersfirstsource/solanabeach/0002/cha/scenarios/BAD_POSTURE/NEGATIVE/ed614310-0c71-4665-ba10-adc2b599b276_0000', 'wn_foods/hayward/0008/cha/scenarios/BAD_POSTURE/NEGATIVE/732af084-48c0-4829-8888-045953bda7bb_0000', 'ppg/cedar_falls/0011/cha/scenarios/BAD_POSTURE/NEGATIVE/9bc71aff-bee0-49c7-9240-85c69df5cc79_0000', 'ppg/cedar_falls/0005/cha/scenarios/BAD_POSTURE/NEGATIVE/ad2d72df-3232-487a-be77-78a85d1476ed_0000'}
#
# fp_with_HM_model - fp_no_filter
# set()
#
# fn_no_filter - fn_with_HM_model
# set()
#
# fn_with_HM_model - fn_no_filter
# {'innovate_manufacturing/knoxville/0009/cha/scenarios/BAD_POSTURE/POSITIVE/418019ea-b249-41cb-9bfc-5e6eecfde9ea_0000'}
