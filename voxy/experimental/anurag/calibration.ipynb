# %% [markdown]
# ### Camera calibration
#
# Following the tutorial from: https://www.learnopencv.com/camera-calibration-using-opencv/

# %%
import sys
import os


sys.path.append('/mnt/disk/ankit/pursuit/third_party')
import cv2
import numpy as np
from matplotlib import pyplot as plt
import pickle as pkl

# CAMERA_NAMES = ['Cam3_1', 'Cam3_2', 'Cam3_3', 'Cam3_4']
CAMERA_NAMES = ['Cam1_1', 'Cam3_5']
# CAMERA_NAMES = ['Cam3_1', 'Cam3_3']
# CAMERA_NAMES = ['Cam3_2', 'Cam3_4']
CALIBRATION_ID = '1'
FOLDER_PATH = '/mnt/disk/ankit/Calibration'
MAX_FRAMES_TO_CONSIDER = 8000
DOWNSAMPLING_RATIO = 10

# %%
# Defining the dimensions of checkerboard
CHECKERBOARD = (15, 10)
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 30, 0.001) # Termination criteria for prediction

# Creating vector to store vectors of 3D points for each checkerboard image
objpoints = []
# Creating vector to store vectors of 2D points for each checkerboard image
imgpoints = [] 


# Defining the world coordinates for 3D points
objp = np.zeros((1, CHECKERBOARD[0] * CHECKERBOARD[1], 3), np.float32)
objp[0,:,:2] = np.mgrid[0:CHECKERBOARD[0], 0:CHECKERBOARD[1]].T.reshape(-1, 2)
for CAMERA_NAME in CAMERA_NAMES:
    # Create a VideoCapture object and read from input file
    # If the input is the camera, pass 0 instead of the video file name
    cap = cv2.VideoCapture('{}/{}.mp4'.format(FOLDER_PATH, CAMERA_NAME))

    # Check if camera opened successfully
    if (cap.isOpened()== False): 
      print("Error opening video stream or file")

    index = 0
    save_folder = '{}/{}_images'.format(FOLDER_PATH, CAMERA_NAME)
    if not os.path.exists(save_folder):
        os.makedirs(save_folder)

    # Read until video is completed
    while(cap.isOpened()):
      # Capture frame-by-frame
        ret, frame = cap.read()
        if ret and index < MAX_FRAMES_TO_CONSIDER:
            if index%DOWNSAMPLING_RATIO == 0:
                print('Processing frame: {}'.format(index))
                img_name = 'frame_{:0>4d}'.format(index)
                gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
                corner_file = '{}/{}.pkl'.format(save_folder, img_name)
                no_corner_file = '{}/{}_no_corner.pkl'.format(save_folder, img_name)
                if os.path.isfile(no_corner_file):
#                     print('Corners already not present: {}'.format(index))
                    index += 1
                    continue
                if os.path.isfile(corner_file):
                    print('Corners already present: {}'.format(index))
                    with open(corner_file, 'rb') as f:
                        corners2 = pkl.load(f)
                        objpoints.append(objp)
                        imgpoints.append(corners2)
                    index += 1
                    continue

                # Find the chess board corners
                # If desired number of corners are found in the image then ret = true
                ret, corners = cv2.findChessboardCorners(gray, CHECKERBOARD, cv2.CALIB_CB_ADAPTIVE_THRESH + cv2.CALIB_CB_NORMALIZE_IMAGE)

                """
                If desired number of corner are detected,
                we refine the pixel coordinates and display 
                them on the images of checker board
                """
                if ret:
                    print('Corners found in frame: {}'.format(index))
                    objpoints.append(objp)
                    # Refining pixel coordinates for given 2d points.
                    corners2 = cv2.cornerSubPix(gray, corners, (11,11),(-1,-1), criteria)
                    imgpoints.append(corners2)

                    # Draw and the corners and write out the image
                    img = cv2.drawChessboardCorners(frame, CHECKERBOARD, corners2, ret)
                    cv2.imwrite(os.path.join(save_folder, img_name + '.jpg'), img)
                    with open(corner_file, 'wb') as f:
                        pkl.dump(corners2, f)
                else:
                    with open(no_corner_file, 'wb') as f:
                        pkl.dump('No Corner Found', f)
                    
            index += 1
        else:
            break

    print('Total Images with corners: {}'.format(len(imgpoints)))

# When everything done, release the video capture object
cap.release()
# Out:
# Processing frame: 0
# Processing frame: 10
# Processing frame: 20
# Processing frame: 30
# Processing frame: 40
# Processing frame: 50
# Processing frame: 60
# Processing frame: 70
# Processing frame: 80
# Processing frame: 90
# Processing frame: 100
# Processing frame: 110
# Processing frame: 120
# Processing frame: 130
# Processing frame: 140
# Processing frame: 150
# Processing frame: 160
# Processing frame: 170
# Processing frame: 180
# Processing frame: 190
# Processing frame: 200
# Processing frame: 210
# Processing frame: 220
# Processing frame: 230
# Processing frame: 240
# Processing frame: 250
# Corners already present: 250
# Processing frame: 260
# Corners already present: 260
# Processing frame: 270
# Corners already present: 270
# Processing frame: 280
# Corners already present: 280
# Processing frame: 290
# Corners already present: 290
# Processing frame: 300
# Corners already present: 300
# Processing frame: 310
# Corners already present: 310
# Processing frame: 320
# Corners already present: 320
# Processing frame: 330
# Corners already present: 330
# Processing frame: 340
# Corners already present: 340
# Processing frame: 350
# Corners already present: 350
# Processing frame: 360
# Corners already present: 360
# Processing frame: 370
# Corners already present: 370
# Processing frame: 380
# Corners already present: 380
# Processing frame: 390
# Corners already present: 390
# Processing frame: 400
# Corners already present: 400
# Processing frame: 410
# Corners already present: 410
# Processing frame: 420
# Processing frame: 430
# Processing frame: 440
# Processing frame: 450
# Processing frame: 460
# Processing frame: 470
# Processing frame: 480
# Corners already present: 480
# Processing frame: 490
# Corners already present: 490
# Processing frame: 500
# Corners already present: 500
# Processing frame: 510
# Corners already present: 510
# Processing frame: 520
# Corners already present: 520
# Processing frame: 530
# Corners already present: 530
# Processing frame: 540
# Corners already present: 540
# Processing frame: 550
# Corners already present: 550
# Processing frame: 560
# Corners already present: 560
# Processing frame: 570
# Corners already present: 570
# Processing frame: 580
# Corners already present: 580
# Processing frame: 590
# Corners already present: 590
# Processing frame: 600
# Corners already present: 600
# Processing frame: 610
# Corners already present: 610
# Processing frame: 620
# Corners already present: 620
# Processing frame: 630
# Corners already present: 630
# Processing frame: 640
# Processing frame: 650
# Corners already present: 650
# Processing frame: 660
# Corners already present: 660
# Processing frame: 670
# Corners already present: 670
# Processing frame: 680
# Corners already present: 680
# Processing frame: 690
# Corners already present: 690
# Processing frame: 700
# Corners already present: 700
# Processing frame: 710
# Corners already present: 710
# Processing frame: 720
# Corners already present: 720
# Processing frame: 730
# Corners already present: 730
# Processing frame: 740
# Corners already present: 740
# Processing frame: 750
# Corners already present: 750
# Processing frame: 760
# Corners already present: 760
# Processing frame: 770
# Corners already present: 770
# Processing frame: 780
# Corners already present: 780
# Processing frame: 790
# Corners already present: 790
# Processing frame: 800
# Corners already present: 800
# Processing frame: 810
# Corners already present: 810
# Processing frame: 820
# Corners already present: 820
# Processing frame: 830
# Processing frame: 840
# Processing frame: 850
# Processing frame: 860
# Processing frame: 870
# Processing frame: 880
# Processing frame: 890
# Processing frame: 900
# Processing frame: 910
# Processing frame: 920
# Corners already present: 920
# Processing frame: 930
# Corners already present: 930
# Processing frame: 940
# Corners already present: 940
# Processing frame: 950
# Corners already present: 950
# Processing frame: 960
# Corners already present: 960
# Processing frame: 970
# Corners already present: 970
# Processing frame: 980
# Corners already present: 980
# Processing frame: 990
# Corners already present: 990
# Processing frame: 1000
# Corners already present: 1000
# Processing frame: 1010
# Corners already present: 1010
# Processing frame: 1020
# Corners already present: 1020
# Processing frame: 1030
# Corners already present: 1030
# Processing frame: 1040
# Corners already present: 1040
# Processing frame: 1050
# Corners already present: 1050
# Processing frame: 1060
# Corners already present: 1060
# Processing frame: 1070
# Processing frame: 1080
# Processing frame: 1090
# Processing frame: 1100
# Processing frame: 1110
# Processing frame: 1120
# Processing frame: 1130
# Processing frame: 1140
# Processing frame: 1150
# Processing frame: 1160
# Processing frame: 1170
# Corners already present: 1170
# Processing frame: 1180
# Corners already present: 1180
# Processing frame: 1190
# Corners already present: 1190
# Processing frame: 1200
# Corners already present: 1200
# Processing frame: 1210
# Corners already present: 1210
# Processing frame: 1220
# Corners already present: 1220
# Processing frame: 1230
# Corners already present: 1230
# Processing frame: 1240
# Corners already present: 1240
# Processing frame: 1250
# Corners already present: 1250
# Processing frame: 1260
# Corners already present: 1260
# Processing frame: 1270
# Corners already present: 1270
# Processing frame: 1280
# Corners already present: 1280
# Processing frame: 1290
# Corners already present: 1290
# Processing frame: 1300
# Corners already present: 1300
# Processing frame: 1310
# Corners already present: 1310
# Processing frame: 1320
# Corners already present: 1320
# Processing frame: 1330
# Corners already present: 1330
# Processing frame: 1340
# Corners already present: 1340
# Processing frame: 1350
# Corners already present: 1350
# Processing frame: 1360
# Corners already present: 1360
# Processing frame: 1370
# Corners already present: 1370
# Processing frame: 1380
# Corners already present: 1380
# Processing frame: 1390
# Corners already present: 1390
# Processing frame: 1400
# Corners already present: 1400
# Processing frame: 1410
# Corners already present: 1410
# Processing frame: 1420
# Corners already present: 1420
# Processing frame: 1430
# Corners already present: 1430
# Processing frame: 1440
# Corners already present: 1440
# Processing frame: 1450
# Corners already present: 1450
# Processing frame: 1460
# Corners already present: 1460
# Processing frame: 1470
# Corners already present: 1470
# Processing frame: 1480
# Corners already present: 1480
# Processing frame: 1490
# Corners already present: 1490
# Processing frame: 1500
# Corners already present: 1500
# Processing frame: 1510
# Corners already present: 1510
# Processing frame: 1520
# Corners already present: 1520
# Processing frame: 1530
# Corners already present: 1530
# Processing frame: 1540
# Corners already present: 1540
# Processing frame: 1550
# Corners already present: 1550
# Processing frame: 1560
# Corners already present: 1560
# Processing frame: 1570
# Corners already present: 1570
# Processing frame: 1580
# Corners already present: 1580
# Processing frame: 1590
# Corners already present: 1590
# Processing frame: 1600
# Corners already present: 1600
# Processing frame: 1610
# Corners already present: 1610
# Processing frame: 1620
# Corners already present: 1620
# Processing frame: 1630
# Processing frame: 1640
# Processing frame: 1650
# Processing frame: 1660
# Processing frame: 1670
# Processing frame: 1680
# Processing frame: 1690
# Processing frame: 1700
# Processing frame: 1710
# Corners already present: 1710
# Processing frame: 1720
# Corners already present: 1720
# Processing frame: 1730
# Corners already present: 1730
# Processing frame: 1740
# Corners already present: 1740
# Processing frame: 1750
# Corners already present: 1750
# Processing frame: 1760
# Corners already present: 1760
# Processing frame: 1770
# Corners already present: 1770
# Processing frame: 1780
# Corners already present: 1780
# Processing frame: 1790
# Corners already present: 1790
# Processing frame: 1800
# Corners already present: 1800
# Processing frame: 1810
# Corners already present: 1810
# Processing frame: 1820
# Corners already present: 1820
# Processing frame: 1830
# Corners already present: 1830
# Processing frame: 1840
# Corners already present: 1840
# Processing frame: 1850
# Processing frame: 1860
# Processing frame: 1870
# Processing frame: 1880
# Processing frame: 1890
# Corners already present: 1890
# Processing frame: 1900
# Corners already present: 1900
# Processing frame: 1910
# Corners already present: 1910
# Processing frame: 1920
# Corners already present: 1920
# Processing frame: 1930
# Corners already present: 1930
# Processing frame: 1940
# Corners already present: 1940
# Processing frame: 1950
# Corners already present: 1950
# Processing frame: 1960
# Corners already present: 1960
# Processing frame: 1970
# Corners already present: 1970
# Processing frame: 1980
# Corners already present: 1980
# Processing frame: 1990
# Corners already present: 1990
# Processing frame: 2000
# Corners already present: 2000
# Processing frame: 2010
# Corners already present: 2010
# Processing frame: 2020
# Processing frame: 2030
# Processing frame: 2040
# Processing frame: 2050
# Processing frame: 2060
# Processing frame: 2070
# Processing frame: 2080
# Processing frame: 2090
# Processing frame: 2100
# Processing frame: 2110
# Processing frame: 2120
# Processing frame: 2130
# Processing frame: 2140
# Processing frame: 2150
# Processing frame: 2160
# Processing frame: 2170
# Processing frame: 2180
# Processing frame: 2190
# Processing frame: 2200
# Processing frame: 2210
# Corners already present: 2210
# Processing frame: 2220
# Corners already present: 2220
# Processing frame: 2230
# Corners already present: 2230
# Processing frame: 2240
# Corners already present: 2240
# Processing frame: 2250
# Corners already present: 2250
# Processing frame: 2260
# Corners already present: 2260
# Processing frame: 2270
# Corners already present: 2270
# Processing frame: 2280
# Corners already present: 2280
# Processing frame: 2290
# Corners already present: 2290
# Processing frame: 2300
# Corners already present: 2300
# Processing frame: 2310
# Corners already present: 2310
# Processing frame: 2320
# Corners already present: 2320
# Processing frame: 2330
# Corners already present: 2330
# Processing frame: 2340
# Corners already present: 2340
# Processing frame: 2350
# Corners already present: 2350
# Processing frame: 2360
# Corners already present: 2360
# Processing frame: 2370
# Corners already present: 2370
# Processing frame: 2380
# Corners already present: 2380
# Processing frame: 2390
# Corners already present: 2390
# Processing frame: 2400
# Corners already present: 2400
# Processing frame: 2410
# Corners already present: 2410
# Processing frame: 2420
# Corners already present: 2420
# Processing frame: 2430
# Corners already present: 2430
# Processing frame: 2440
# Processing frame: 2450
# Corners already present: 2450
# Processing frame: 2460
# Processing frame: 2470
# Processing frame: 2480
# Processing frame: 2490
# Corners already present: 2490
# Processing frame: 2500
# Corners already present: 2500
# Processing frame: 2510
# Corners already present: 2510
# Processing frame: 2520
# Corners already present: 2520
# Processing frame: 2530
# Corners already present: 2530
# Processing frame: 2540
# Corners already present: 2540
# Processing frame: 2550
# Corners already present: 2550
# Processing frame: 2560
# Corners already present: 2560
# Processing frame: 2570
# Corners already present: 2570
# Processing frame: 2580
# Corners already present: 2580
# Processing frame: 2590
# Corners already present: 2590
# Processing frame: 2600
# Corners already present: 2600
# Processing frame: 2610
# Corners already present: 2610
# Processing frame: 2620
# Corners already present: 2620
# Processing frame: 2630
# Corners already present: 2630
# Processing frame: 2640
# Corners already present: 2640
# Processing frame: 2650
# Corners already present: 2650
# Processing frame: 2660
# Corners already present: 2660
# Processing frame: 2670
# Corners already present: 2670
# Processing frame: 2680
# Corners already present: 2680
# Processing frame: 2690
# Corners already present: 2690
# Processing frame: 2700
# Corners already present: 2700
# Processing frame: 2710
# Corners already present: 2710
# Processing frame: 2720
# Corners already present: 2720
# Processing frame: 2730
# Corners already present: 2730
# Processing frame: 2740
# Corners already present: 2740
# Processing frame: 2750
# Corners already present: 2750
# Processing frame: 2760
# Corners already present: 2760
# Processing frame: 2770
# Corners already present: 2770
# Processing frame: 2780
# Corners already present: 2780
# Processing frame: 2790
# Corners already present: 2790
# Processing frame: 2800
# Corners already present: 2800
# Processing frame: 2810
# Corners already present: 2810
# Processing frame: 2820
# Corners already present: 2820
# Processing frame: 2830
# Corners already present: 2830
# Processing frame: 2840
# Corners already present: 2840
# Processing frame: 2850
# Corners already present: 2850
# Processing frame: 2860
# Corners already present: 2860
# Processing frame: 2870
# Corners already present: 2870
# Processing frame: 2880
# Corners already present: 2880
# Processing frame: 2890
# Corners already present: 2890
# Processing frame: 2900
# Corners already present: 2900
# Processing frame: 2910
# Corners already present: 2910
# Processing frame: 2920
# Corners already present: 2920
# Processing frame: 2930
# Corners already present: 2930
# Processing frame: 2940
# Corners already present: 2940
# Processing frame: 2950
# Corners already present: 2950
# Processing frame: 2960
# Corners already present: 2960
# Processing frame: 2970
# Corners already present: 2970
# Processing frame: 2980
# Corners already present: 2980
# Processing frame: 2990
# Corners already present: 2990
# Processing frame: 3000
# Corners already present: 3000
# Processing frame: 3010
# Corners already present: 3010
# Processing frame: 3020
# Corners already present: 3020
# Processing frame: 3030
# Processing frame: 3040
# Processing frame: 3050
# Processing frame: 3060
# Processing frame: 3070
# Processing frame: 3080
# Processing frame: 3090
# Processing frame: 3100
# Processing frame: 3110
# Processing frame: 3120
# Processing frame: 3130
# Processing frame: 3140
# Processing frame: 3150
# Processing frame: 3160
# Processing frame: 3170
# Processing frame: 3180
# Processing frame: 3190
# Processing frame: 3200
# Processing frame: 3210
# Processing frame: 3220
# Processing frame: 3230
# Processing frame: 3240
# Processing frame: 3250
# Processing frame: 3260
# Processing frame: 3270
# Processing frame: 3280
# Processing frame: 3290
# Processing frame: 3300
# Processing frame: 3310
# Processing frame: 5000
# Corners already present: 5000
# Processing frame: 5010
# Corners already present: 5010
# Processing frame: 5020
# Corners already present: 5020
# Processing frame: 5030
# Corners already present: 5030
# Processing frame: 5040
# Corners already present: 5040
# Processing frame: 5050
# Corners already present: 5050
# Processing frame: 5060
# Corners already present: 5060
# Processing frame: 5070
# Corners already present: 5070
# Processing frame: 5080
# Corners already present: 5080
# Processing frame: 5090
# Corners already present: 5090
# Processing frame: 5100
# Corners already present: 5100
# Processing frame: 5110
# Corners already present: 5110
# Processing frame: 5120
# Corners already present: 5120
# Processing frame: 5130
# Corners already present: 5130
# Processing frame: 5140
# Corners already present: 5140
# Processing frame: 5150
# Corners already present: 5150
# Processing frame: 5160
# Corners already present: 5160
# Processing frame: 5170
# Corners already present: 5170
# Processing frame: 5180
# Corners already present: 5180
# Processing frame: 5190
# Corners already present: 5190
# Processing frame: 5200
# Corners already present: 5200
# Processing frame: 5210
# Corners already present: 5210
# Processing frame: 5220
# Corners already present: 5220
# Processing frame: 5230
# Corners already present: 5230
# Processing frame: 5240
# Corners already present: 5240
# Processing frame: 5250
# Corners already present: 5250
# Processing frame: 5260
# Corners already present: 5260
# Processing frame: 5270
# Corners already present: 5270
# Processing frame: 5280
# Corners already present: 5280
# Processing frame: 5290
# Corners already present: 5290
# Processing frame: 5300
# Corners already present: 5300
# Processing frame: 5310
# Corners already present: 5310
# Processing frame: 5320
# Corners already present: 5320
# Processing frame: 5330
# Corners already present: 5330
# Processing frame: 5340
# Corners already present: 5340
# Processing frame: 5350
# Corners already present: 5350
# Processing frame: 5360
# Corners already present: 5360
# Processing frame: 5370
# Corners already present: 5370
# Processing frame: 5380
# Corners already present: 5380
# Processing frame: 5390
# Corners already present: 5390
# Processing frame: 5400
# Corners already present: 5400
# Processing frame: 5410
# Corners already present: 5410
# Processing frame: 5420
# Corners already present: 5420
# Processing frame: 5430
# Corners already present: 5430
# Processing frame: 5440
# Corners already present: 5440
# Processing frame: 5450
# Corners already present: 5450
# Processing frame: 5460
# Corners already present: 5460
# Processing frame: 5470
# Corners already present: 5470
# Processing frame: 5480
# Corners already present: 5480
# Processing frame: 5490
# Corners already present: 5490
# Processing frame: 5500
# Corners already present: 5500
# Processing frame: 5510
# Corners already present: 5510
# Processing frame: 5520
# Corners already present: 5520
# Processing frame: 5530
# Corners already present: 5530
# Processing frame: 5540
# Corners already present: 5540
# Processing frame: 5550
# Processing frame: 5560
# Corners already present: 5560
# Processing frame: 5570
# Corners already present: 5570
# Processing frame: 5580
# Corners already present: 5580
# Processing frame: 5590
# Corners already present: 5590
# Processing frame: 5600
# Corners already present: 5600
# Processing frame: 5610
# Corners already present: 5610
# Processing frame: 5620
# Corners already present: 5620
# Processing frame: 5630
# Corners already present: 5630
# Processing frame: 5640
# Corners already present: 5640
# Processing frame: 5650
# Corners already present: 5650
# Processing frame: 5660
# Corners already present: 5660
# Processing frame: 5670
# Corners already present: 5670
# Processing frame: 5680
# Processing frame: 5690
# Processing frame: 5700
# Processing frame: 5710
# Processing frame: 5720
# Corners already present: 5720
# Processing frame: 5730
# Corners already present: 5730
# Processing frame: 5740
# Corners already present: 5740
# Processing frame: 5750
# Processing frame: 5760
# Processing frame: 5770
# Processing frame: 5780
# Processing frame: 5790
# Processing frame: 5800
# Processing frame: 5810
# Processing frame: 5820
# Processing frame: 5830
# Processing frame: 5840
# Processing frame: 5850
# Processing frame: 5860
# Processing frame: 5870
# Processing frame: 5880
# Processing frame: 5890
# Processing frame: 5900
# Processing frame: 5910
# Processing frame: 5920
# Processing frame: 5930
# Processing frame: 5940
# Processing frame: 5950
# Processing frame: 5960
# Processing frame: 5970
# Processing frame: 5980
# Total Images with corners: 395
# Processing frame: 0
# Corners already present: 0
# Processing frame: 10
# Corners already present: 10
# Processing frame: 20
# Corners already present: 20
# Processing frame: 30
# Corners already present: 30
# Processing frame: 40
# Corners already present: 40
# Processing frame: 50
# Processing frame: 60
# Processing frame: 70
# Processing frame: 80
# Processing frame: 90
# Processing frame: 100
# Corners already present: 100
# Processing frame: 110
# Corners already present: 110
# Processing frame: 120
# Corners already present: 120
# Processing frame: 130
# Corners already present: 130
# Processing frame: 140
# Corners already present: 140
# Processing frame: 150
# Corners already present: 150
# Processing frame: 160
# Corners already present: 160
# Processing frame: 170
# Corners already present: 170
# Processing frame: 180
# Corners already present: 180
# Processing frame: 190
# Corners already present: 190
# Processing frame: 200
# Corners already present: 200
# Processing frame: 210
# Corners already present: 210
# Processing frame: 220
# Corners already present: 220
# Processing frame: 230
# Corners already present: 230
# Processing frame: 240
# Corners already present: 240
# Processing frame: 250
# Corners already present: 250
# Processing frame: 260
# Corners already present: 260
# Processing frame: 270
# Corners already present: 270
# Processing frame: 280
# Corners already present: 280
# Processing frame: 290
# Corners already present: 290
# Processing frame: 300
# Corners already present: 300
# Processing frame: 310
# Corners already present: 310
# Processing frame: 320
# Corners already present: 320
# Processing frame: 330
# Corners already present: 330
# Processing frame: 340
# Corners already present: 340
# Processing frame: 350
# Corners already present: 350
# Processing frame: 360
# Corners already present: 360
# Processing frame: 370
# Corners already present: 370
# Processing frame: 380
# Corners already present: 380
# Processing frame: 390
# Corners already present: 390
# Processing frame: 400
# Corners already present: 400
# Processing frame: 410
# Corners already present: 410
# Processing frame: 420
# Corners already present: 420
# Processing frame: 430
# Corners already present: 430
# Processing frame: 440
# Corners already present: 440
# Processing frame: 450
# Corners already present: 450
# Processing frame: 460
# Corners already present: 460
# Processing frame: 470
# Corners already present: 470
# Processing frame: 480
# Corners already present: 480
# Processing frame: 490
# Corners already present: 490
# Processing frame: 500
# Corners already present: 500
# Processing frame: 510
# Corners already present: 510
# Processing frame: 520
# Corners already present: 520
# Processing frame: 530
# Corners already present: 530
# Processing frame: 540
# Corners already present: 540
# Processing frame: 550
# Corners already present: 550
# Processing frame: 560
# Corners already present: 560
# Processing frame: 570
# Corners already present: 570
# Processing frame: 580
# Corners already present: 580
# Processing frame: 590
# Corners already present: 590
# Processing frame: 600
# Corners already present: 600
# Processing frame: 610
# Corners already present: 610
# Processing frame: 620
# Corners already present: 620
# Processing frame: 630
# Corners already present: 630
# Processing frame: 640
# Corners already present: 640
# Processing frame: 650
# Corners already present: 650
# Processing frame: 660
# Corners already present: 660
# Processing frame: 670
# Corners already present: 670
# Processing frame: 680
# Corners already present: 680
# Processing frame: 690
# Corners already present: 690
# Processing frame: 700
# Corners already present: 700
# Processing frame: 710
# Processing frame: 720
# Processing frame: 730
# Processing frame: 740
# Processing frame: 750
# Processing frame: 760
# Processing frame: 770
# Corners already present: 770
# Processing frame: 780
# Corners already present: 780
# Processing frame: 790
# Corners already present: 790
# Processing frame: 800
# Corners already present: 800
# Processing frame: 810
# Corners already present: 810
# Processing frame: 820
# Corners already present: 820
# Processing frame: 830
# Corners already present: 830
# Processing frame: 840
# Corners already present: 840
# Processing frame: 850
# Corners already present: 850
# Processing frame: 860
# Corners already present: 860
# Processing frame: 870
# Corners already present: 870
# Processing frame: 880
# Corners already present: 880
# Processing frame: 890
# Corners already present: 890
# Processing frame: 900
# Corners already present: 900
# Processing frame: 910
# Corners already present: 910
# Processing frame: 920
# Corners already present: 920
# Processing frame: 930
# Corners already present: 930
# Processing frame: 940
# Corners already present: 940
# Processing frame: 950
# Corners already present: 950
# Processing frame: 960
# Corners already present: 960
# Processing frame: 970
# Corners already present: 970
# Processing frame: 980
# Corners already present: 980
# Processing frame: 990
# Corners already present: 990
# Processing frame: 1000
# Corners already present: 1000
# Processing frame: 1010
# Corners already present: 1010
# Processing frame: 1020
# Corners already present: 1020
# Processing frame: 1030
# Corners already present: 1030
# Processing frame: 1040
# Corners already present: 1040
# Processing frame: 1050
# Corners already present: 1050
# Processing frame: 1060
# Corners already present: 1060
# Processing frame: 1070
# Corners already present: 1070
# Processing frame: 1080
# Corners already present: 1080
# Processing frame: 1090
# Corners already present: 1090
# Processing frame: 1100
# Corners already present: 1100
# Processing frame: 1110
# Corners already present: 1110
# Processing frame: 1120
# Corners already present: 1120
# Processing frame: 1130
# Corners already present: 1130
# Processing frame: 1140
# Corners already present: 1140
# Processing frame: 1150
# Processing frame: 1160
# Processing frame: 1170
# Processing frame: 1180
# Corners already present: 1180
# Processing frame: 1190
# Corners already present: 1190
# Processing frame: 1200
# Corners already present: 1200
# Processing frame: 1210
# Corners already present: 1210
# Processing frame: 1220
# Corners already present: 1220
# Processing frame: 1230
# Corners already present: 1230
# Processing frame: 1240
# Corners already present: 1240
# Processing frame: 1250
# Corners already present: 1250
# Processing frame: 1260
# Corners already present: 1260
# Processing frame: 1270
# Corners already present: 1270
# Processing frame: 1280
# Corners already present: 1280
# Processing frame: 1290
# Corners already present: 1290
# Processing frame: 1300
# Corners already present: 1300
# Processing frame: 1310
# Corners already present: 1310
# Processing frame: 1320
# Corners already present: 1320
# Processing frame: 1330
# Corners already present: 1330
# Processing frame: 1340
# Processing frame: 1350
# Corners already present: 1350
# Processing frame: 1360
# Corners already present: 1360
# Processing frame: 1370
# Corners already present: 1370
# Processing frame: 1380
# Corners already present: 1380
# Processing frame: 1390
# Corners already present: 1390
# Processing frame: 1400
# Corners already present: 1400
# Processing frame: 1410
# Corners already present: 1410
# Processing frame: 1420
# Processing frame: 1430
# Processing frame: 1440
# Processing frame: 1450
# Processing frame: 1460
# Processing frame: 1470
# Processing frame: 1480
# Processing frame: 1490
# Processing frame: 1500
# Corners already present: 1500
# Processing frame: 1510
# Corners already present: 1510
# Processing frame: 1520
# Processing frame: 1530
# Processing frame: 1540
# Processing frame: 1550
# Processing frame: 1560
# Processing frame: 1570
# Processing frame: 1580
# Processing frame: 1590
# Processing frame: 1600
# Processing frame: 1610
# Processing frame: 1620
# Processing frame: 1630
# Processing frame: 1640
# Processing frame: 1650
# Processing frame: 1660
# Processing frame: 1670
# Processing frame: 1680
# Processing frame: 1690
# Processing frame: 1700
# Processing frame: 1710
# Processing frame: 1720
# Processing frame: 1730
# Processing frame: 1740
# Processing frame: 1750
# Processing frame: 1760
# Processing frame: 1770
# Processing frame: 1780
# Processing frame: 1790
# Processing frame: 1800
# Processing frame: 1810
# Processing frame: 1820
# Processing frame: 1830
# Processing frame: 1840
# Processing frame: 1850
# Processing frame: 1860
# Processing frame: 1870
# Processing frame: 1880
# Processing frame: 1890
# Processing frame: 1900
# Processing frame: 1910
# Processing frame: 1920
# Processing frame: 1930
# Processing frame: 1940
# Processing frame: 1950
# Processing frame: 1960
# Processing frame: 1970
# Processing frame: 1980
# Processing frame: 1990
# Processing frame: 2000
# Processing frame: 2010
# Processing frame: 2020
# Corners already present: 2020
# Processing frame: 2030
# Corners already present: 2030
# Processing frame: 2040
# Corners already present: 2040
# Processing frame: 2050
# Corners already present: 2050
# Processing frame: 2060
# Corners already present: 2060
# Processing frame: 2070
# Corners already present: 2070
# Processing frame: 2080
# Corners already present: 2080
# Processing frame: 2090
# Corners already present: 2090
# Processing frame: 2100
# Corners already present: 2100
# Processing frame: 2110
# Corners already present: 2110
# Processing frame: 2120
# Corners already present: 2120
# Processing frame: 2130
# Corners already present: 2130
# Processing frame: 2140
# Corners already present: 2140
# Processing frame: 2150
# Corners already present: 2150
# Processing frame: 2160
# Corners already present: 2160
# Processing frame: 2170
# Corners already present: 2170
# Processing frame: 2180
# Corners already present: 2180
# Processing frame: 2190
# Corners already present: 2190
# Processing frame: 2200
# Corners already present: 2200
# Processing frame: 2210
# Corners already present: 2210
# Processing frame: 2220
# Processing frame: 2230
# Processing frame: 2240
# Processing frame: 2250
# Processing frame: 2260
# Processing frame: 2270
# Processing frame: 2280
# Processing frame: 2290
# Processing frame: 2300
# Processing frame: 2310
# Processing frame: 2320
# Corners already present: 2320
# Processing frame: 2330
# Corners already present: 2330
# Processing frame: 2340
# Corners already present: 2340
# Processing frame: 2350
# Corners already present: 2350
# Processing frame: 2360
# Corners already present: 2360
# Processing frame: 2370
# Corners already present: 2370
# Processing frame: 2380
# Corners already present: 2380
# Processing frame: 2390
# Corners already present: 2390
# Processing frame: 2400
# Corners already present: 2400
# Processing frame: 2410
# Corners already present: 2410
# Processing frame: 2420
# Corners already present: 2420
# Processing frame: 2430
# Corners already present: 2430
# Processing frame: 2440
# Corners already present: 2440
# Processing frame: 2450
# Corners already present: 2450
# Processing frame: 2460
# Corners already present: 2460
# Processing frame: 2470
# Corners already present: 2470
# Processing frame: 2480
# Corners already present: 2480
# Processing frame: 2490
# Corners already present: 2490
# Processing frame: 2500
# Corners already present: 2500
# Processing frame: 2510
# Corners already present: 2510
# Processing frame: 2520
# Processing frame: 2530
# Processing frame: 2540
# Processing frame: 2550
# Processing frame: 2560
# Processing frame: 2570
# Processing frame: 2580
# Processing frame: 2590
# Processing frame: 2600
# Processing frame: 2610
# Processing frame: 2620
# Processing frame: 2630
# Corners already present: 2630
# Processing frame: 2640
# Corners already present: 2640
# Processing frame: 2650
# Corners already present: 2650
# Processing frame: 2660
# Corners already present: 2660
# Processing frame: 2670
# Corners already present: 2670
# Processing frame: 2680
# Corners already present: 2680
# Processing frame: 2690
# Corners already present: 2690
# Processing frame: 2700
# Corners already present: 2700
# Processing frame: 2710
# Corners already present: 2710
# Processing frame: 2720
# Corners already present: 2720
# Processing frame: 2730
# Corners already present: 2730
# Processing frame: 2740
# Corners already present: 2740
# Processing frame: 2750
# Corners already present: 2750
# Processing frame: 2760
# Corners already present: 2760
# Processing frame: 2770
# Corners already present: 2770
# Processing frame: 2780
# Corners already present: 2780
# Processing frame: 2790
# Processing frame: 2800
# Processing frame: 2810
# Processing frame: 2820
# Processing frame: 2830
# Processing frame: 2840
# Corners already present: 2840
# Processing frame: 2850
# Corners already present: 2850
# Processing frame: 2860
# Corners already present: 2860
# Processing frame: 2870
# Corners already present: 2870
# Processing frame: 2880
# Corners already present: 2880
# Processing frame: 2890
# Corners already present: 2890
# Processing frame: 2900
# Corners already present: 2900
# Processing frame: 2910
# Corners already present: 2910
# Processing frame: 2920
# Corners already present: 2920
# Processing frame: 2930
# Corners already present: 2930
# Processing frame: 2940
# Corners already present: 2940
# Processing frame: 2950
# Corners already present: 2950
# Processing frame: 2960
# Processing frame: 2970
# Processing frame: 2980
# Processing frame: 2990
# Processing frame: 3000
# Processing frame: 3010
# Processing frame: 3020
# Processing frame: 3030
# Processing frame: 3040
# Processing frame: 3050
# Processing frame: 3060
# Processing frame: 3070
# Processing frame: 3080
# Processing frame: 3090
# Corners already present: 3090
# Processing frame: 3100
# Corners already present: 3100
# Processing frame: 3110
# Corners already present: 3110
# Processing frame: 3120
# Corners already present: 3120
# Processing frame: 3130
# Corners already present: 3130
# Processing frame: 3140
# Corners already present: 3140
# Processing frame: 3150
# Corners already present: 3150
# Processing frame: 3160
# Processing frame: 3170
# Processing frame: 3180
# Processing frame: 3190
# Processing frame: 3200
# Processing frame: 3210
# Processing frame: 3220
# Processing frame: 3230
# Corners already present: 3230
# Processing frame: 3240
# Corners already present: 3240
# Processing frame: 3250
# Processing frame: 3260
# Processing frame: 3270
# Processing frame: 3280
# Processing frame: 3290
# Corners already present: 3290
# Processing frame: 3300
# Corners already present: 4800
# Processing frame: 4810
# Corners already present: 4810
# Processing frame: 4820
# Processing frame: 4830
# Corners already present: 4830
# Processing frame: 4840
# Processing frame: 4850
# Processing frame: 4860
# Processing frame: 4870
# Processing frame: 4880
# Processing frame: 4890
# Processing frame: 4900
# Processing frame: 4910
# Corners already present: 4910
# Processing frame: 4920
# Corners already present: 4920
# Processing frame: 4930
# Corners already present: 4930
# Processing frame: 4940
# Corners already present: 4940
# Processing frame: 4950
# Corners already present: 4950
# Processing frame: 4960
# Corners already present: 4960
# Processing frame: 4970
# Corners already present: 4970
# Processing frame: 4980
# Corners already present: 4980
# Processing frame: 4990
# Corners already present: 4990
# Processing frame: 5000
# Corners already present: 5000
# Processing frame: 5010
# Corners already present: 5010
# Processing frame: 5020
# Corners already present: 5020
# Processing frame: 5030
# Processing frame: 5040
# Corners already present: 5040
# Processing frame: 5050
# Corners already present: 5050
# Processing frame: 5060
# Corners already present: 5060
# Processing frame: 5070
# Corners already present: 5070
# Processing frame: 5080
# Corners already present: 5080
# Processing frame: 5090
# Corners already present: 5090
# Processing frame: 5100
# Corners already present: 5100
# Processing frame: 5110
# Processing frame: 5120
# Processing frame: 5130
# Processing frame: 5140
# Corners already present: 5140
# Processing frame: 5150
# Corners already present: 5150
# Processing frame: 5160
# Corners already present: 5160
# Processing frame: 5170
# Processing frame: 5180
# Corners already present: 5180
# Processing frame: 5190
# Corners already present: 5190
# Processing frame: 5200
# Corners already present: 5200
# Processing frame: 5210
# Corners already present: 5210
# Processing frame: 5220
# Corners already present: 5220
# Processing frame: 5230
# Corners already present: 5230
# Processing frame: 5240
# Corners already present: 5240
# Processing frame: 5250
# Corners already present: 5250
# Processing frame: 5260
# Corners already present: 5260
# Processing frame: 5270
# Corners already present: 5270
# Processing frame: 5280
# Corners already present: 5280
# Processing frame: 5290
# Corners already present: 5290
# Processing frame: 5300
# Corners already present: 5300
# Processing frame: 5310
# Corners already present: 5310
# Processing frame: 5320
# Corners already present: 5320
# Processing frame: 5330
# Corners already present: 5330
# Processing frame: 5340
# Corners already present: 5340
# Processing frame: 5350
# Corners already present: 5350
# Processing frame: 5360
# Corners already present: 5360
# Processing frame: 5370
# Corners already present: 5370
# Processing frame: 5380
# Corners already present: 5380
# Processing frame: 5390
# Corners already present: 5390
# Processing frame: 5400
# Corners already present: 5400
# Processing frame: 5410
# Corners already present: 5410
# Processing frame: 5420
# Corners already present: 5420
# Processing frame: 5430
# Corners already present: 5430
# Processing frame: 5440
# Corners already present: 5440
# Processing frame: 5450
# Corners already present: 5450
# Processing frame: 5460
# Corners already present: 5460
# Processing frame: 5470
# Corners already present: 5470
# Processing frame: 5480
# Corners already present: 5480
# Processing frame: 5490
# Corners already present: 5490
# Processing frame: 5500
# Processing frame: 5510
# Processing frame: 5520
# Processing frame: 5530
# Processing frame: 5540
# Processing frame: 5550
# Processing frame: 5560
# Processing frame: 5570
# Processing frame: 5580
# Processing frame: 5590
# Processing frame: 5600
# Processing frame: 5610
# Processing frame: 6750
# Processing frame: 6760
# Processing frame: 6770
# Processing frame: 6780
# Processing frame: 6790
# Processing frame: 6800
# Processing frame: 6810
# Processing frame: 6820
# Processing frame: 6830
# Corners already present: 6830
# Processing frame: 6840
# Processing frame: 6850
# Processing frame: 6860
# Processing frame: 6870
# Processing frame: 6880
# Processing frame: 6890
# Processing frame: 6900
# Processing frame: 6910
# Processing frame: 6920
# Processing frame: 6930
# Processing frame: 6940
# Processing frame: 6950
# Processing frame: 6960
# Processing frame: 6970
# Processing frame: 6980
# Processing frame: 6990
# Processing frame: 7000
# Processing frame: 7010
# Processing frame: 7020
# Processing frame: 7030
# Processing frame: 7040
# Processing frame: 7050
# Processing frame: 7060
# Processing frame: 7070
# Processing frame: 7080
# Processing frame: 7090
# Processing frame: 7100
# Processing frame: 7110
# Processing frame: 7120
# Processing frame: 7130
# Processing frame: 7140
# Processing frame: 7150
# Processing frame: 7160
# Processing frame: 7170
# Processing frame: 7180
# Processing frame: 7190
# Processing frame: 7200
# Processing frame: 7210
# Processing frame: 7220
# Processing frame: 7230
# Processing frame: 7240
# Processing frame: 7250
# Processing frame: 7260
# Processing frame: 7270
# Processing frame: 7280
# Processing frame: 7290
# Processing frame: 7300
# Processing frame: 7310
# Processing frame: 7320
# Processing frame: 7330
# Processing frame: 7340
# Processing frame: 7350
# Processing frame: 7360
# Processing frame: 7370
# Processing frame: 7380
# Processing frame: 7390
# Processing frame: 7400
# Processing frame: 7410
# Processing frame: 7420
# Processing frame: 7430
# Processing frame: 7440
# Processing frame: 7450
# Processing frame: 7460
# Processing frame: 7470
# Processing frame: 7480
# Processing frame: 7490
# Processing frame: 7500
# Processing frame: 7510
# Processing frame: 7520
# Processing frame: 7530
# Processing frame: 7540
# Processing frame: 7550
# Processing frame: 7560
# Processing frame: 7570
# Processing frame: 7580
# Processing frame: 7590
# Processing frame: 7600
# Processing frame: 7610
# Processing frame: 7620
# Processing frame: 7630
# Processing frame: 7640
# Processing frame: 7650
# Processing frame: 7660
# Processing frame: 7670
# Processing frame: 7680
# Processing frame: 7690
# Processing frame: 7700
# Processing frame: 7710
# Processing frame: 7720
# Processing frame: 7730
# Processing frame: 7740
# Processing frame: 7750
# Processing frame: 7760
# Processing frame: 7770
# Processing frame: 7780
# Processing frame: 7790
# Processing frame: 7800
# Processing frame: 7810
# Processing frame: 7820
# Processing frame: 7830
# Processing frame: 7840
# Processing frame: 7850
# Total Images with corners: 812

# %%
print('Running Calibration ....')
"""
Performing camera calibration by 
passing the value of known 3D points (objpoints)
and corresponding pixel coordinates of the 
detected corners (imgpoints)
"""
ret, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(objpoints, imgpoints, gray.shape[::-1], None, None, None, None, cv2.CALIB_RATIONAL_MODEL)
print('Done Calibration ....')
# Out:
# Running Calibration ....
# Done Calibration ....

# %%
CAMERA_NAMES = ['Cam1_1']
import pickle as pkl
intrinsic_matrix = mtx
distortion_params = dist
# transform the matrix and distortion coefficients to writable lists
data = {'intrinsic_matrix': np.asarray(intrinsic_matrix),
        'distortion_params': np.asarray(distortion_params)}


# Save the calibration paramters
for CAMERA_NAME in CAMERA_NAMES:
    calibration_file = '{}/{}_{}_calibration.pkl'.format(FOLDER_PATH, CAMERA_NAME, CALIBRATION_ID)
    with open(calibration_file, "wb") as f:
        pkl.dump(data, f)

# %%
# Create a VideoCapture object and read from input file
# If the input is the camera, pass 0 instead of the video file name
# Create a VideoCapture object and read from input file
# If the input is the camera, pass 0 instead of the video file name
MAX_FRAMES_TO_CONSIDER = 100
for CAMERA_NAME in CAMERA_NAMES:
    # Load the calibration parameters from the disk
    calibration_file = '{}/{}_{}_calibration.pkl'.format(FOLDER_PATH, CAMERA_NAME, CALIBRATION_ID)
    with open(calibration_file, "rb") as f:
        data = pkl.load(f)
    intrinsic_matrix = data['intrinsic_matrix']
    distortion_params = data['distortion_params']
    cap = cv2.VideoCapture('{}/{}.mp4'.format(FOLDER_PATH, CAMERA_NAME))

    # Check if camera opened successfully
    if (cap.isOpened()== False): 
      print("Error opening video stream or file")

    index = 0
    save_folder = '{}/{}_{}_undistorted_images'.format(FOLDER_PATH, CAMERA_NAME, CALIBRATION_ID)
    if not os.path.exists(save_folder):
        os.makedirs(save_folder)

    # Read until video is completed
    while(cap.isOpened()):
      # Capture frame-by-frame
        ret, frame = cap.read()
        if ret and index < MAX_FRAMES_TO_CONSIDER:
            if index%DOWNSAMPLING_RATIO == 0:
                print('Processing frame: {}'.format(index))
                img_name = 'frame_{:0>4d}'.format(index)
                undistorted_frame = cv2.undistort(frame, intrinsic_matrix, distortion_params)
                concatenated_frame = cv2.hconcat([frame, undistorted_frame])
                cv2.imwrite(os.path.join(save_folder, img_name + '.jpg'), concatenated_frame)
            index += 1
        else:
            break
# Out:
# Processing frame: 0
# Processing frame: 10
# Processing frame: 20
# Processing frame: 30
# Processing frame: 40
# Processing frame: 50
# Processing frame: 60
# Processing frame: 70
# Processing frame: 80
# Processing frame: 90

# %%
# Load the calibration parameters from the disk
calibration_file = '{}/{}_{}_calibration.pkl'.format(FOLDER_PATH, 'Cam1_1', CALIBRATION_ID)
with open(calibration_file, "rb") as f:
    data1 = pkl.load(f)

# %%
# Load the calibration parameters from the disk
calibration_file = '{}/{}_{}_calibration.pkl'.format(FOLDER_PATH, 'Cam3_5', CALIBRATION_ID)
with open(calibration_file, "rb") as f:
    data2 = pkl.load(f)

# %%
data1
# Out:
# {'intrinsic_matrix': array([[2.15589860e+03, 0.00000000e+00, 1.87484766e+03],
#         [0.00000000e+00, 2.16206199e+03, 1.13432230e+03],
#         [0.00000000e+00, 0.00000000e+00, 1.00000000e+00]]),
#  'distortion_params': array([[-0.17066782,  0.0546047 , -0.00052563,  0.00101097,  0.01582123,
#           0.22518689, -0.09158746,  0.06303651,  0.        ,  0.        ,
#           0.        ,  0.        ,  0.        ,  0.        ]])}

# %%
data2
# Out:
# {'intrinsic_matrix': array([[2.24125510e+03, 0.00000000e+00, 2.04236578e+03],
#         [0.00000000e+00, 2.22198442e+03, 1.10313253e+03],
#         [0.00000000e+00, 0.00000000e+00, 1.00000000e+00]]),
#  'distortion_params': array([[-0.17058646,  0.04787551,  0.00056111,  0.0009748 , -0.0014346 ,
#           0.21827147, -0.08390574,  0.02755975,  0.        ,  0.        ,
#           0.        ,  0.        ,  0.        ,  0.        ]])}
